# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv ('cleaned.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  difficulty                        titles  sci_info  eng_lang  \
# 0           0           1           b002_LittleBear.txt         0         1
# 1           1           1       b003_AreYouMyMother.txt         0         1
# 2           2           1      b004_GreenEggsAndHam.txt         0         1
# 3           3           1        b005_Putmeinthezoo.txt         0         1
# 4           4           1  b006_FrogAndToadTogether.txt         0         1
#
#    syl_per_word  ws_per_sents  not_easy_words  avg_wd_length  polysyls  ...  \
# 0      1.170068      7.736842        0.000000       3.809524  0.006803  ...
# 1      1.120650      5.623377        0.041570       3.330254  0.000000  ...
# 2      1.010013      5.278912        0.039948       3.097938  0.000000  ...
# 3      1.015873      5.040000        0.031746       3.055556  0.000000  ...
# 4      1.103082      7.294574        0.013284       3.804995  0.006908  ...
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'difficulty', 'titles', 'sci_info', 'eng_lang',
#        'syl_per_word', 'ws_per_sents', 'not_easy_words', 'avg_wd_length',
#        'polysyls', 'monosyls', 'modals_per_sent', 'adj', 'verb', 'adp', 'adv',
#        'sconj', 'cconj', 'aux', 'det', 'avg_verb_length', 'avg_adj_length',
#        'avg_adv_length', 'flesch_score', 'ari_score', 'dale_score', 'smog',
#        'gunning_fog', 'cli', 'linsear_raw', 'linsear'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Unnamed: 0  difficulty    sci_info    eng_lang  syl_per_word  \
# count  178.000000  178.000000  178.000000  178.000000    178.000000
# mean    95.775281    4.207865    0.595506    0.404494      1.321803
# std     56.233422    1.596799    0.492178    0.492178      0.131527
# min      0.000000    1.000000    0.000000    0.000000      1.010013
# 25%     46.250000    3.000000    0.000000    0.000000      1.229330
# 50%     97.500000    5.000000    1.000000    0.000000      1.309078
# 75%    143.750000    6.000000    1.000000    1.000000      1.408310
# max    191.000000    6.000000    1.000000    1.000000      1.662620
#
#        ws_per_sents  not_easy_words  avg_wd_length    polysyls    monosyls  \
# count    178.000000      178.000000     178.000000  178.000000  178.000000
# mean      15.903154        0.160404       4.353222    0.068051    0.767600
# std        6.029614        0.074900       0.376147    0.044989    0.071123
# ...

# %%
df.difficulty.hist()

# %%
df.flesch_score.hist()

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0DF3B6A0>,
# ...
#       dtype=object)

# %%
df.modals_per_sent.hist()

# %%
df.boxplot (column = 'flesch_score')

# %%
df.boxplot (column = 'polysyls')

# %%
df[['flesch_score','not_easy_words', 'dale_score','syl_per_word', 'polysyls','linsear']].corr()
# Out:
#                 flesch_score  not_easy_words  dale_score  syl_per_word  \
# flesch_score        1.000000       -0.861111   -0.919358     -0.954360
# not_easy_words     -0.861111        1.000000    0.984648      0.893939
# dale_score         -0.919358        0.984648    1.000000      0.904051
# syl_per_word       -0.954360        0.893939    0.904051      1.000000
# polysyls           -0.925980        0.844750    0.859144      0.966864
# linsear            -0.904876        0.672918    0.789089      0.741152
#
#                 polysyls   linsear
# flesch_score   -0.925980 -0.904876
# not_easy_words  0.844750  0.672918
# dale_score      0.859144  0.789089
# syl_per_word    0.966864  0.741152
# polysyls        1.000000  0.741491
# linsear         0.741491  1.000000

# %%
#source: https://seaborn.pydata.org/examples/many_pairwise_correlations.html

# Compute the correlation matrix
corr = df.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=np.bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .7})

# %%
df.corr()
# Out:
#                  difficulty  sci_info  eng_lang  syl_per_word  ws_per_sents  \
# difficulty         1.000000  0.172288 -0.172288      0.695506      0.691783
# sci_info           0.172288  1.000000 -1.000000      0.514851      0.304113
# eng_lang          -0.172288 -1.000000  1.000000     -0.514851     -0.304113
# syl_per_word       0.695506  0.514851 -0.514851      1.000000      0.639230
# ws_per_sents       0.691783  0.304113 -0.304113      0.639230      1.000000
# not_easy_words     0.683284  0.458278 -0.458278      0.893939      0.591958
# avg_wd_length      0.626930  0.467995 -0.467995      0.906822      0.576084
# polysyls           0.669638  0.492785 -0.492785      0.966864      0.626400
# monosyls          -0.678590 -0.506875  0.506875     -0.967614     -0.624890
# modals_per_sent    0.334884  0.198134 -0.198134      0.262911      0.437574
# adj                0.603645  0.341678 -0.341678      0.694840      0.835871
# ...

# %%
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(df[['sci_info','eng_lang','difficulty']].corr(),vmax=1, center=0, cmap=cmap,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
